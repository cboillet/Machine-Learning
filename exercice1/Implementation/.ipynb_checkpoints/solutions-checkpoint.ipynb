# %%
import numpy as np
from pylab import *
from mpl_toolkits.mplot3d.axes3d import Axes3D
# %pylab inline
import scipy.spatial, scipy.linalg
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['linalg', 'draw_if_interactive', 'random', 'fft', 'power', 'info']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import utils
# %pylab inline
utils.plot_demo(angle=120)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def LLE(matrice):    #matrice de N donnees en D dimensions
    N=len(matrice[:,1]);
    int D=len(matrice[1,:]);
    return;
# Out:
#   File "<ipython-input-8-c4a6cf24b19f>", line 2
#     int N=len(matrice[:,1]);
#         ^
# SyntaxError: invalid syntax
